# %%
vector,matrix,x,producto=[],[],[],1.0
m=int(input('Valor de m:'))
n=int(input('Valor de n:'))
for z in range(0,n):
    x.append(n*0.0)

if(m==n):
    for i in range(m): #filas
        matrix.append([])
        for j in range(n):  #columnas
            matrix[i].append(0)

    for k in range(n):
        vector.append(0)
    
    print ('Introduce la matriz de coeficientes y el vector solución')
    for z in range(0,m):
        for y in range(0,n):
            matrix[z][y]=float((input("\nElemento a"+str(z+1)+""+str(y+1)+": ")))
        vector[z]=float((input('\nSolucion '+str(z+1)+': ')))
    print ("\nLa matriz original es: ",matrix)
    print ("\nEl vector solucion original es: ",vector)
    
    p,k=0,0
    p=k
    big = abs(matrix[k][k])
    for i in range(k+1,n):
        dummy = abs(matrix[i][k])
        if (dummy>big):
            big=dummy
            p=i
    if (p!=k):
        for j in range(k,n):
            dummy=matrix[p][j]
            matrix[p][j]=matrix[k][j]
            matrix[k][j]=dummy
        dummy=vector[p]
        vector[p]=vector[k]
        vector[k]=dummy
    
    for z in range (0,m):
        for y in range(z+1,m):
            factor=(matrix[y][z]/matrix[z][z])
            vector[y]=vector[y]-(factor*vector[y])
            for w in range(0,n):
                matrix[y][w]=matrix[y][w]-(factor*matrix[z][w])
    #sustitución hacia atrás
    x[m-1]=vector[m-1]/matrix[m-1][m-1]
    
    for y in range(m-2,-1,-1):
        suma=0
        for w in range(0,n):
            suma=suma+matrix[y][w]*x[w]
        x[y]=(vector[y]-suma)/matrix[y][y]
        
    print ('\nResultado de la matriz\n',matrix)
    print ('\nResultado del vector\n',vector)
    print ('\nRespuestas de las incognitas:\n',x)
    for i in range(len(x)):
        print ("\nX= ",(i+1,x[i]))
    
    for i in range (0,n):
        for j in range (0,n):
            if(i==j):
                producto=producto*matrix[i][j]
    print ("El determinante es= ",producto)
else:
    print ("No se puede usar Gauss, no es una matriz cuadrada")
# Out:
# Valor de m:3
# Valor de n:3
# Introduce la matriz de coeficientes y el vector solución
#
# Elemento a11: 2
#
# Elemento a12: 9
#
# Elemento a13: 7
#
# Solucion 1: 4
#
# Elemento a21: 45
#
# Elemento a22: 5
#
# Elemento a23: 6
#
# Solucion 2: 2
#
# Elemento a31: 1
#
# Elemento a32: 4
#
# Elemento a33: 8
#
# Solucion 3: 8
#
# La matriz original es:  [[2.0, 9.0, 7.0], [45.0, 5.0, 6.0], [1.0, 4.0, 8.0]]
#
# El vector solucion original es:  [4.0, 2.0, 8.0]
#
# Resultado de la matriz
#  [[45.0, 5.0, 6.0], [0.0, 8.777777777777779, 6.733333333333333], [0.0, 0.0, 4.883544303797468]]
#
# Resultado del vector
#  [2.0, 3.8222222222222224, 4.356680731364276]
#
# Respuestas de las incognitas:
#  [-0.04684995249792385, -0.24888783895811867, 0.8921145095328611]
#
# X=  (1, -0.04684995249792385)
#
# X=  (2, -0.24888783895811867)
#
# X=  (3, 0.8921145095328611)
# El determinante es=  1929.0
